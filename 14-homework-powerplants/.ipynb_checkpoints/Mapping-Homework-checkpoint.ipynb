# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
from shapely.geometry import Polygon
# %matplotlib inline
import fiona

# %%
# Make a map of power plants in the US, color coded by type
powerplants = pd.read_csv("powerplants.csv")

points = powerplants.apply(lambda row: Point(row.Longitude, row.Latitude), axis=1)
powerplants = gpd.GeoDataFrame(powerplants, geometry=points)
# gallery = gallery.to_crs(gallery.crs)
powerplants.crs = {'init': 'epsg:5071'}

powerplants.head()
# Out:
#    Plant_Code          Plant_Name        Utility_Na  Utility_ID  \
# 0           2        Bankhead Dam  Alabama Power Co         195
# 1           3               Barry  Alabama Power Co         195
# 2           4  Walter Bouldin Dam  Alabama Power Co         195
# 3           7             Gadsden  Alabama Power Co         195
# 4           8              Gorgas  Alabama Power Co         195
#
#          sector_nam       City      County    Zip            Street_Add  \
# 0  Electric Utility  Northport  Tuscaloosa  35476    19001 Lock 17 Road
# 1  Electric Utility      Bucks      Mobile  36512      North Highway 43
# 2  Electric Utility   Wetumpka      Elmore  36092  750 Bouldin Dam Road
# 3  Electric Utility    Gadsden      Etowah  35903     1000 Goodyear Ave
# 4  Electric Utility    Parrish      Walker  35580       460 Gorgas Road
#
#       PrimSource                  ...                   Wind_MW  Geo_MW  \
# ...

# %%
states = gpd.read_file("/Users/amandajames/Desktop/14-homework-powerplants/cb_2016_us_state_500k/cb_2016_us_state_500k.shp")
states.crs = {'init': 'epsg:5071'}
states.head(10)
# Out:
#       AFFGEOID          ALAND        AWATER GEOID LSAD                  NAME  \
# 0  0400000US01   131173688951    4593686489    01   00               Alabama
# 1  0400000US02  1477946266785  245390495931    02   00                Alaska
# 2  0400000US04   294198560125    1027346486    04   00               Arizona
# 3  0400000US05   134771517596    2960191698    05   00              Arkansas
# 4  0400000US06   403501101370   20466718403    06   00            California
# 5  0400000US08   268429343790    1175112870    08   00              Colorado
# 6  0400000US09    12542638347    1815476291    09   00           Connecticut
# 7  0400000US10     5047194742    1398720828    10   00              Delaware
# 8  0400000US11      158364992      18633403    11   00  District of Columbia
# 9  0400000US13   149169848456    4741100880    13   00               Georgia
#
#   STATEFP   STATENS STUSPS                                           geometry
# ...

# %%
powerplants.plot()

# %%
top = 51.3457868 # north lat
left = -124.7844079 # west long
right = -65.9513812 # east long
bottom =  20.7433195

bounds = [
            [
              left,
              bottom
            ],
            [
              right,
              bottom
            ],
            [
              right,
              top
            ],
            [
              left,
              top
            ],
            [
              left,
              bottom
            ]
]

# Turn the coordinates into a shapely polygon
powerplantbox = Polygon(bounds)

# Make sure our state CRS is in lat/lng by using to_crs
# You could also just have done
# states = states.to_crs({'init': 'epsg:4326'})
# and converted it permanently once instead of doing it multiple times later on
# ax = gpd.GeoDataFrame(newdf)
# newdf.crs={'init':'epsg:4326'}


powerplants = powerplants[powerplants.to_crs({'init': 'epsg:5071'}).within(powerplantbox)]

# %%
powerplants.plot()

# %%
top = 51.3457868 # north lat
left = -124.7844079 # west long
right = -65.9513812 # east long
bottom =  20.7433195

bounds = [
            [
              left,
              bottom
            ],
            [
              right,
              bottom
            ],
            [
              right,
              top
            ],
            [
              left,
              top
            ],
            [
              left,
              bottom
            ]
]

# Turn the coordinates into a shapely polygon
statesbox = Polygon(bounds)

# Make sure our state CRS is in lat/lng by using to_crs
# You could also just have done
# states = states.to_crs({'init': 'epsg:4326'})
# and converted it permanently once instead of doing it multiple times later on
# ax = gpd.GeoDataFrame(newdf)
# newdf.crs={'init':'epsg:4326'}


states = states[states.to_crs({'init': 'epsg:5071'}).within(statesbox)]

# %%
ax=states.plot()

# %%
# ax = powerplants.plot(column= 'PrimSource', figsize=(30,10), cmap='BuGn')

# %%
plants_in_states = gpd.sjoin(states.reset_index(), powerplants, how='inner', op='intersects')
plants_in_states.head(10)
# Out:
#    index     AFFGEOID         ALAND      AWATER GEOID LSAD     NAME STATEFP  \
# 0      0  0400000US01  131173688951  4593686489    01   00  Alabama      01
# 0      0  0400000US01  131173688951  4593686489    01   00  Alabama      01
# 0      0  0400000US01  131173688951  4593686489    01   00  Alabama      01
# 0      0  0400000US01  131173688951  4593686489    01   00  Alabama      01
# 0      0  0400000US01  131173688951  4593686489    01   00  Alabama      01
# 0      0  0400000US01  131173688951  4593686489    01   00  Alabama      01
# 0      0  0400000US01  131173688951  4593686489    01   00  Alabama      01
# 0      0  0400000US01  131173688951  4593686489    01   00  Alabama      01
# 0      0  0400000US01  131173688951  4593686489    01   00  Alabama      01
# 0      0  0400000US01  131173688951  4593686489    01   00  Alabama      01
#
#     STATENS STUSPS    ...     Solar_MW  Wind_MW  Geo_MW Other_MW  \
# 0  01779775     AL    ...          0.0      0.0     NaN      NaN
# ...

# %%
# plants_in_states.plot()

# %%
plants_in_states['plant_count'] = plants_in_states.apply(lambda row:powerplants.within(row.geometry).sum(), axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-5dd027e2800a> in <module>()
# ----> 1 plants_in_states['plant_count'] = plants_in_states.apply(lambda row:powerplants.within(row.geometry).sum(), axis=1)
#
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4260                         f, axis,
#    4261                         reduce=reduce,
# -> 4262                         ignore_failures=ignore_failures)
#    4263             else:
#    4264                 return self._apply_broadcast(f, axis)
#
# /usr/local/lib/python3.6/site-packages/pandas/core/frame.py in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4316                     labels = self._get_agg_axis(axis)
#    4317                     result = lib.reduce(values, func, axis=axis, dummy=dummy,
# ...

# %%
plants_in_states.plot(column='plant_count',figsize=(24,24),cmap='Reds')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2441             try:
# -> 2442                 return self._engine.get_loc(key)
#    2443             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5280)()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5126)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20523)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item (pandas/_libs/hashtable.c:20477)()
#
# KeyError: 'plant_count'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
# Make a map of air quality stations, color coded by average air quality
